# %%
for index, value in enumerate(['a', 'b', 'c']):
    print(index, value)

print(enumerate(['a', 'b', 'c']))

# %%
nums = [1, 1, 1, 3, 4]
freq = [[] for i in range(len(nums) + 1)]
print(freq)

# %%
#Common Python Built-in Functions

print("Hello, World!")
name = input("Enter your name: ")
length = len([1, 2, 3, 4, 5])
data_type = type(42)
num = int("42")
text = str(42)
value = float("3.14")
my_list = list(range(5))
my_dict = dict([('a', 1), ('b', 2)])
numbers = range(1, 6)  # Generates numbers from 1 to 5
total = sum([1, 2, 3, 4, 5])
maximum = max([4, 8, 2, 9])
minimum = min([4, 8, 2, 9])
absolute_value = abs(-42)
rounded_value = round(3.14159, 2)  # Rounds to 2 decimal places
sorted_list = sorted([3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5])
for index, value in enumerate(['a', 'b', 'c']):
    print(index, value)
names = ['Alice', 'Bob', 'Charlie']
scores = [85, 92, 78]
combined = list(zip(names, scores))
def square(x):
    return x ** 2

squared_numbers = list(map(square, [1, 2, 3, 4, 5]))


result = any([False, True, False])
result = all([True, True, True])
def is_even(x):
    return x % 2 == 0

even_numbers = list(filter(is_even, [1, 2, 3, 4, 5, 6]))
from functools import reduce

def add(x, y):
    return x + y

result = reduce(add, [1, 2, 3, 4, 5])
character = chr(65)  # Returns 'A'
ascii_value = ord('A')  # Returns 65
absolute_value = abs(-42)
result = pow(2, 3)  # Returns 8 (2^3)
hex_value = hex(255)  # Returns '0xff'
octal_value = oct(8)  # Returns '0o10'
binary_value = bin(7)  # Returns '0b111'
formatted = "Hello, {}! You scored {} points.".format("Alice", 85)
sorted_list = sorted([3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5])
maximum = max([4, 8, 2, 9])
minimum = min([4, 8, 2, 9])
my_list = [1, 2, 3, 4, 5]
sliced = my_list[slice(1, 4)]  # Returns [2, 3, 4]

# %%
#Common Python Built-in String Manipulation Functions

num_str = str(42)
char = chr(65)  # 'A'
ascii_value = ord('A')  # 65
formatted = "Hello, {}!".format("Alice")
length = len("Hello, World!")
combined = "Hello, " + "World!"
words = ["Hello", "World"]
sentence = " ".join(words)
words = "Hello, World!".split(", ")
text = "   Some text with spaces   "
stripped_text = text.strip()
text = "Hello, World!"
replaced_text = text.replace("World", "Python")
text = "Hello, World!"
uppercase_text = text.upper()
text = "Hello, World!"
lowercase_text = text.lower()
text = "hello, world!"
capitalized_text = text.capitalize()
text = "hello, world!"
title_text = text.title()
text = "Hello, World!"
starts_with_hello = text.startswith("Hello")
ends_with_exclamation = text.endswith("!")
text = "Hello, World!"
index = text.find("World")
text = "Hello, Hello, World!"
count = text.count("Hello")
is_alpha = "Hello".isalpha()  # True
is_digit = "12345".isdigit()  # True
is_alphanumeric = "Hello123".isalnum()  # True

# %%
#Common Python Built-in List Manipulation Functions

my_list = list(range(1, 6))  # Converts a range to a list [1, 2, 3, 4, 5]
length = len([1, 2, 3, 4, 5])
my_list = [1, 2, 3]
my_list.append(4)
my_list = [1, 2, 3]
my_list.extend([4, 5, 6])
my_list = [1, 2, 3]
my_list.insert(1, 4)  # Inserts 4 at index 1
my_list = [1, 2, 3, 2]
my_list.remove(2)  # Removes the first occurrence of 2
my_list = [1, 2, 3]
removed_element = my_list.pop(1)  # Removes and returns element at index 1 (2)
my_list = [1, 2, 3]
del my_list[1]  # Deletes element at index 1 (2)
my_list = [1, 2, 3]
my_list.clear()  # Removes all elements
my_list = [1, 2, 3]
my_list.reverse()  # Reverses the list to [3, 2, 1]
my_list = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
my_list.sort()  # Sorts in ascending order
original_list = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
sorted_list = sorted(original_list)  # Returns a new sorted list
my_list = [1, 2, 3, 2, 4, 2]
count = my_list.count(2)  # Counts the occurrences of 2 (3)
my_list = [1, 2, 3, 2, 4, 2]
index = my_list.index(2)  # Returns the index of the first 2 (1)
original_list = [1, 2, 3]
copied_list = original_list.copy()
squares = [x ** 2 for x in [1, 2, 3, 4, 5]]

# %%
# Declare a set
my_set = {1, 2, 3, 4, 4}  # Duplicate elements are automatically removed

# Access elements of the set
print(my_set)  # Output: {1, 2, 3, 4}

# Add an element to the set
my_set.add(5)

# Remove an element from the set
my_set.remove(3)

# Check if an element is in the set
is_in_set = 2 in my_set  # True

# Perform set operations like union, intersection, and difference
set1 = {1, 2, 3}
set2 = {3, 4, 5}

union_result = set1 | set2  # Union: {1, 2, 3, 4, 5}
intersection_result = set1 & set2  # Intersection: {3}
difference_result = set1 - set2  # Difference: {1, 2}

# %%
# Declare a tuple
my_tuple = (1, 2, 3)

# Access elements of the tuple
print(my_tuple[0])  # Output: 1

# Tuple unpacking
x, y, z = my_tuple
print(x, y, z)  # Output: 1 2 3

# Create a single-element tuple
single_element_tuple = (4,)  # Note the trailing comma

# Use tuples for multiple return values from functions
def get_name_and_age():
    return "Alice", 30

name, age = get_name_and_age()
print(name)  # Output: Alice
print(age)   # Output: 30
